# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sys
sys.path.append('../model/main_model')

from some_functions import get_db


art_db = get_db(r'C:\Users\a814811\OneDrive - Atos\RecommenderSystem\art_clean_wt_all_popularity.csv')
user_db = get_db(r'C:\Users\a814811\OneDrive - Atos\RecommenderSystem\readers.csv')

# %%
x = pd.merge(user_db, art_db[art_db['nzz_id'].isin(user_db['nzz_id'])][['nzz_id','department']], on='nzz_id')
z = x.groupby(['user_id','department'])['user_id'].count().reset_index(name='count')
z.values.tolist()[:10]
# Out:
# [[1, 'Digital', 2],
#  [1, 'Feuilleton', 1],
#  [1, 'Schweiz', 2],
#  [2, 'Feuilleton', 2],
#  [2, 'Panorama', 1],
#  [2, 'Sport', 1],
#  [2, 'Tessin', 1],
#  [3, 'Feuilleton', 1],
#  [3, 'Meinung', 2],
#  [3, 'Mobilität', 7]]

# %%
c = ['user_id']
c.extend(x['department'].unique())

v = np.zeros([1000,len(c)])
v[:,0] = np.arange(1,1001)

res = pd.DataFrame(v,columns=c)

for item in z.values.tolist():
    res.loc[res[res['user_id']==item[0]].index,item[1]] = item[2]
corr = res.iloc[:,1:].corr()

# %%
pd.set_option('display.max_columns', None)
# corr[(corr.iloc[:] != 1) & (corr.iloc[:] > 0.1)]
# corr.loc["Sport","Euro 2016"]
corr.head(2)
# Out:
#          Schweiz  Digital  Feuilleton  Panorama     Sport    Tessin  \
# Schweiz  1.00000  0.02439   -0.032836 -0.007969 -0.006468  0.094309
# Digital  0.02439  1.00000   -0.035133  0.006203 -0.030009  0.068873
#
#          Mobilität     Video   Meinung  Wirtschaft  Leserdebatte    Archiv  \
# Schweiz  -0.052185  0.094025 -0.039131    0.005819      0.101655  0.052838
# Digital  -0.039323  0.042112  0.039781   -0.015807      0.039411  0.015318
#
#          International     NZZaS  Gesellschaft  Finanzen  News-Ticker  \
# Schweiz       0.004277 -0.012925     -0.000416 -0.034346     0.030978
# Digital       0.017074 -0.025116     -0.034670  0.035763     0.068397
#
#            Zürich  Startseite  Euro 2016   Unknown  Bildstrecken  \
# Schweiz  0.068290    0.083495   0.061824  0.080066      0.029256
# Digital  0.004331    0.048014   0.058584  0.030361      0.043442
#
#          Storytelling  Wissenschaft    Spiele  Jahresrückblick 2016  \
# ...

# %%
i = 0
print(corr.index[i])corr.sort_values(by=corr.index[0i)[corr.index[0i]
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Schweiz
# <style  type="text/css" >
# #T_08e87_row0_col0,#T_08e87_row1_col1,#T_08e87_row2_col2,#T_08e87_row3_col3,#T_08e87_row4_col4,#T_08e87_row5_col5,#T_08e87_row6_col6,#T_08e87_row7_col7,#T_08e87_row8_col8,#T_08e87_row9_col9,#T_08e87_row10_col10,#T_08e87_row11_col11,#T_08e87_row12_col12,#T_08e87_row13_col13,#T_08e87_row14_col14,#T_08e87_row15_col15,#T_08e87_row16_col16,#T_08e87_row17_col17,#T_08e87_row18_col18,#T_08e87_row19_col19,#T_08e87_row20_col20,#T_08e87_row21_col21,#T_08e87_row22_col22,#T_08e87_row23_col23,#T_08e87_row24_col24,#T_08e87_row25_col25,#T_08e87_row26_col26,#T_08e87_row27_col27{
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...
