# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sys
sys.path.append('../model/main_model')

from some_functions import get_db


art_db = get_db(r'C:\Users\a814811\OneDrive - Atos\RecommenderSystem\art_clean_wt_all_popularity.csv')
user_db = get_db(r'C:\Users\a814811\OneDrive - Atos\RecommenderSystem\readers.csv')

# %%
x = pd.merge(user_db, art_db[art_db['nzz_id'].isin(user_db['nzz_id'])][['nzz_id','department']], on='nzz_id')
z = x.groupby(['user_id','department'])['user_id'].count().reset_index(name='count')
z.values.tolist()[:10]
# Out:
# [[1, 'Digital', 2],
#  [1, 'Feuilleton', 1],
#  [1, 'Schweiz', 2],
#  [2, 'Feuilleton', 2],
#  [2, 'Panorama', 1],
#  [2, 'Sport', 1],
#  [2, 'Tessin', 1],
#  [3, 'Feuilleton', 1],
#  [3, 'Meinung', 2],
#  [3, 'Mobilität', 7]]

# %%
c = ['user_id']
c.extend(x['department'].unique())

v = np.zeros([1000,len(c)])
v[:,0] = np.arange(1,1001)

res = pd.DataFrame(v,columns=c)

for item in z.values.tolist():
    res.loc[res[res['user_id']==item[0]].index,item[1]] = item[2]
corr = res.iloc[:,1:].corr()
corr.head()
# Out:
#              Schweiz   Digital  Feuilleton  Panorama     Sport    Tessin  \
# Schweiz     1.000000  0.024390   -0.032836 -0.007969 -0.006468  0.094309
# Digital     0.024390  1.000000   -0.035133  0.006203 -0.030009  0.068873
# Feuilleton -0.032836 -0.035133    1.000000 -0.015815 -0.015871  0.061575
# Panorama   -0.007969  0.006203   -0.015815  1.000000 -0.015668  0.041696
# Sport      -0.006468 -0.030009   -0.015871 -0.015668  1.000000 -0.020346
#
#             Mobilität     Video   Meinung  Wirtschaft  ...  Startseite  \
# Schweiz     -0.052185  0.094025 -0.039131    0.005819  ...    0.083495
# Digital     -0.039323  0.042112  0.039781   -0.015807  ...    0.048014
# Feuilleton  -0.030567  0.022179 -0.021209   -0.042322  ...    0.019805
# Panorama    -0.062715  0.051150 -0.001042   -0.016649  ...    0.005436
# Sport       -0.005470  0.053144  0.012416    0.025331  ...    0.063920
#
#             Euro 2016   Unknown  Bildstrecken  Storytelling  Wissenschaft  \
# Schweiz      0.061824  0.080066      0.029256      0.037862     -0.030270
# Digital      0.058584  0.030361      0.043442      0.024539     -0.035117
# Feuilleton   0.047157  0.067105      0.008740      0.031230      0.026940
# Panorama     0.078858  0.059505      0.040089      0.075067      0.012110
# Sport        0.050356  0.015008      0.071831      0.032945     -0.015609
#
#               Spiele  Jahresrückblick 2016  Marktplatz  Briefing
# Schweiz     0.062703              0.072630   -0.029345  0.033886
# Digital     0.033511              0.098096    0.066447  0.024675
# Feuilleton  0.056022              0.058993    0.069243  0.048626
# Panorama    0.036316              0.029898    0.082875 -0.009032
# Sport       0.118569              0.000369    0.007485  0.084694
#
# [5 rows x 28 columns]

# %%
# Briefing              ...   -0.005504   0.041729  0.027894      0.039045
#
#                       Storytelling  Wissenschaft    Spiele  \
# Schweiz                   0.037862     -0.030270  0.062703
# Digital                   0.024539     -0.035117  0.033511
# Feuilleton                0.031230      0.026940  0.056022
# Panorama                  0.075067      0.012110  0.036316
# Sport                     0.032945     -0.015609  0.118569
# Tessin                    0.034189      0.034155  0.062647
# Mobilität                 0.071976      0.000202  0.043833
# Video                     0.083524      0.017876  0.105922
# Meinung                   0.032366      0.002625  0.016048
# Wirtschaft                0.025198     -0.005473  0.029271
# Leserdebatte              0.024435      0.065093  0.012292
# Archiv                    0.026278      0.071145  0.045657
# International             0.035471     -0.024756  0.062830
# NZZaS                    -0.008096     -0.050493  0.069861
# Gesellschaft              0.125286      0.015531  0.104190
# Finanzen                  0.025437      0.044993  0.040269
# News-Ticker               0.097277      0.048541  0.039544
# Zürich                   -0.003268     -0.006251  0.067858
# Startseite                0.045260      0.029229  0.028757
# Euro 2016                 0.022866      0.049692  0.084681
# Unknown                   0.063004      0.056463  0.103250
# Bildstrecken              0.085526      0.071855  0.074789
# Storytelling              1.000000      0.108437  0.041464
# Wissenschaft              0.108437      1.000000  0.020651
# Spiele                    0.041464      0.020651  1.000000
# Jahresrückblick 2016      0.007825      0.007662  0.052900
# Marktplatz                0.023749      0.003033  0.054332
# Briefing                  0.086283      0.062468  0.061638
#
#                       Jahresrückblick 2016  Marktplatz  Briefing
# Schweiz                           0.072630   -0.029345  0.033886
# Digital                           0.098096    0.066447  0.024675
# Feuilleton                        0.058993    0.069243  0.048626
# Panorama                          0.029898    0.082875 -0.009032
# Sport                             0.000369    0.007485  0.084694
# Tessin                            0.022723    0.061129 -0.000759
# Mobilität                         0.050692    0.051330  0.044053
# Video                            -0.002604    0.024982  0.084649
# Meinung                           0.059233    0.054912  0.100867
# Wirtschaft                        0.027195    0.068308  0.036821
# Leserdebatte                      0.032112    0.028968  0.032966
# Archiv                            0.013407    0.048440  0.085005
# International                     0.074790    0.118223  0.068849
# NZZaS                             0.038889    0.056808  0.054845
# Gesellschaft                      0.052838    0.058132  0.042605
# Finanzen                          0.067883    0.067061  0.083738
# News-Ticker                       0.090231   -0.026582  0.040918
# Zürich                            0.066104    0.002725  0.070816
# Startseite                        0.068709    0.026281 -0.005504
# Euro 2016                         0.070327    0.036789  0.041729
# Unknown                           0.151508   -0.014502  0.027894
# Bildstrecken                      0.027704    0.032467  0.039045
# Storytelling                      0.007825    0.023749  0.086283
# Wissenschaft                      0.007662    0.003033  0.062468
# Spiele                            0.052900    0.054332  0.061638
# Jahresrückblick 2016              1.000000    0.009044  0.006978
# Marktplatz                        0.009044    1.000000  0.027918
# Briefing                          0.006978    0.027918  1.000000
#
# [28 rows x 28 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-ed31b84b7beb> in <module>
# ----> 1 corr.get_value()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_value'
